# %%
from hail import *
hc = HailContext(tmp_dir = '/nvme/tmp/shusson')

# %%
vds_path = '/nvme/marpin/MGRB_phase2_hs37d5x/GATK3_fastq2gvcf-hs37d5x-1.0_split-combine_genotype_vqsr_hail/MGRB.phase2.SNPtier12.match.vqsr.minrep.locusannot.WGStier12.unrelated.tgp.hrc.gnomad.dbsnp.clinvar.cato.eigen.vep.vds'
vds = hc.read(vds_path)

# %%
vds = vds.drop_samples()

# %%
vds.summarize()

# %%
vds.write('/nvme/tmp/shusson/mgrb.vds')

# %%
vds = hc.read('/nvme/tmp/shusson/mgrb.vds')

# %%
vds.summarize()
# Out:
# Summary(samples=0, variants=74045272, call_rate=nan, contigs=['X', '12', '8', '19', '4', '15', '11', '9', 'Y', '22', '13', '16', '5', '10', '21', '6', '1', '17', '14', 'MT', '20', '2', '18', '7', '3'], multiallelics=6195847, snps=66545550, mnps=0, insertions=8180960, deletions=9419976, complex=149, star=3547445, max_alleles=50)

# %%
from pprint import pprint
pprint(vds.variant_schema)
# Out:
# Struct{
#      variant: Struct{
#          qual: Double,
#          filters: Set[String],
#          metrics: Struct{
#              sample_counts: Struct{
#                  female: Long,
#                  male: Long,
#                  total: Long
#              },
#              chromatid_counts: Struct{
#                  female: Double,
#                  male: Double,
#                  total: Double
#              },
#              gatk: Struct{
#                  AN: Int,
#                  BaseQRankSum: Double,
#                  ClippingRankSum: Double,
#                  DB: Boolean,
#                  DP: Int,
#                  DS: Boolean,
#                  END: Int,
#                  ExcessHet: Double,
#                  FS: Double,
#                  HaplotypeScore: Double,
#                  InbreedingCoeff: Double,
#                  MQ: Double,
#                  MQRankSum: Double,
#                  NEGATIVE_TRAIN_SITE: Boolean,
#                  POSITIVE_TRAIN_SITE: Boolean,
#                  QD: Double,
#                  RAW_MQ: Double,
#                  ReadPosRankSum: Double,
#                  SOR: Double,
#                  VQSLOD: Double,
#                  culprit: String
#              }
#          }
#      },
#      genotypes: Struct{
#          counts: Struct{
#              female: Array[Int],
#              male: Array[Int],
#              total: Array[Int]
#          }
#      },
#      alleles: Array[Struct{
#          metrics: Struct{
#              allele_counts: Struct{
#                  female: Double,
#                  male: Double,
#                  total: Double
#              },
#              allele_frequencies: Struct{
#                  female: Double,
#                  male: Double,
#                  total: Double
#              },
#              gatk: Struct{
#                  AC: Int,
#                  AF: Double,
#                  MLEAC: Int,
#                  MLEAF: Double
#              }
#          },
#          annotation: Struct{
#              rsid: String,
#              vep: Struct{
#                  consequences: Struct{
#                      feature: Struct{
#                          id: String,
#                          type: String,
#                          biotype: String,
#                          strand: Int,
#                          canonical: String
#                      },
#                      position_in_feature: Struct{
#                          cDNA: String,
#                          CDS: String,
#                          protein: String,
#                          exon: String,
#                          intron: String,
#                          overlapping_domains: Array[String]
#                      },
#                      variant_class: String,
#                      distance_from_feature: Int,
#                      consequences: Array[String],
#                      impact_class: String,
#                      codon_change: String,
#                      residue_change: String,
#                      motif_disruption: Struct{
#                          motif: String,
#                          motif_pos: Int,
#                          high_inf_pos: String,
#                          motif_score_change: Float
#                      }
#                  },
#                  predictions: Struct{
#                      ClinVar: Array[String],
#                      PolyPhen: String,
#                      SIFT: String
#                  },
#                  HGVS: Struct{
#                      HGVSc: String,
#                      HGVSp: String,
#                      HGVS_offset: Int
#                  },
#                  population_frequencies: Struct{
#                      TGP: Struct{
#                          AF: Float,
#                          AFR_AF: Float,
#                          AMR_AF: Float,
#                          EAS_AF: Float,
#                          EUR_AF: Float,
#                          SAS_AF: Float
#                      },
#                      ESP: Struct{
#                          AA_AF: Float,
#                          EA_AF: Float
#                      },
#                      GnomAD: Struct{
#                          AF: Float,
#                          AFR_AF: Float,
#                          AMR_AF: Float,
#                          ASJ_AF: Float,
#                          EAS_AF: Float,
#                          FIN_AF: Float,
#                          NFE_AF: Float,
#                          OTH_AF: Float,
#                          SAS_AF: Float
#                      },
#                      MAX_AF: Float,
#                      MAX_AF_POPS: Array[String]
#                  },
#                  cross_references: Struct{
#                      Ensembl_gene: String,
#                      Ensembl_protein: String,
#                      PUBMED: Array[Int],
#                      CCDS: String,
#                      SWISSPROT: String,
#                      UNIPARC: String,
#                      symbol: String,
#                      symbol_source: String,
#                      HGNC: Int,
#                      existing_variation: String
#                  }
#              },
#              clinvar: Struct{
#                  AlleleID: Int,
#                  ClinicalSignificance: Array[String],
#                  ClinSigSimple: Int,
#                  rsid: Int,
#                  ReviewStatus: String,
#                  NumberSubmitters: Int
#              },
#              predictions: Struct{
#                  CATO: Struct{
#                      score: Double,
#                      motif: String,
#                      strand: Int,
#                      motifpos: Int,
#                      celltypes: Array[String]
#                  },
#                  Eigen: Struct{
#                      EigenRaw: Double,
#                      EigenPhred: Double,
#                      EigenPCRaw: Double,
#                      EigenPCPhred: Double
#                  }
#              },
#              freqs: Struct{
#                  tgp: Struct{
#                      AC: Int,
#                      AF: Double,
#                      NS: Int,
#                      AN: Int,
#                      AF_EAS: Double,
#                      AF_EUR: Double,
#                      AF_AFR: Double,
#                      AF_AMR: Double,
#                      AF_SAS: Double,
#                      AC_Hail: Int,
#                      AF_Hail: Double,
#                      NS_Hail: Int
#                  },
#                  hrc: Struct{
#                      AC: Int,
#                      AN: Int,
#                      AF: Double,
#                      AC_EXCLUDING_1000G: Int,
#                      AN_EXCLUDING_1000G: Int,
#                      AF_EXCLUDING_1000G: Double
#                  },
#                  gnomad: Struct{
#                      AC: Int,
#                      AF: Double,
#                      AN: Int,
#                      AC_AFR: Int,
#                      AC_AMR: Int,
#                      AC_ASJ: Int,
#                      AC_EAS: Int,
#                      AC_FIN: Int,
#                      AC_NFE: Int,
#                      AC_OTH: Int,
#                      AN_AFR: Int,
#                      AN_AMR: Int,
#                      AN_ASJ: Int,
#                      AN_EAS: Int,
#                      AN_FIN: Int,
#                      AN_NFE: Int,
#                      AN_OTH: Int,
#                      AF_AFR: Double,
#                      AF_AMR: Double,
#                      AF_ASJ: Double,
#                      AF_EAS: Double,
#                      AF_FIN: Double,
#                      AF_NFE: Double,
#                      AF_OTH: Double
#                  }
#              }
#          }
#      }],
#      locus: Struct{
#          badCoverage_dist: Int,
#          badCoverage: Boolean,
#          badComplexity_dist: Int,
#          badComplexity: Boolean,
#          badRepeat_dist: Int,
#          badRepeat: Boolean,
#          badMappability_dist: Int,
#          badMappability: Boolean,
#          badEncodeExcluded_dist: Int,
#          badEncodeExcluded: Boolean,
#          goodGiaBHighConf_dist: Int,
#          goodGiaBHighConf: Boolean,
#          badPAR: Boolean,
#          tier: Int
#      }
#  }
